# %%
import pandas as pd
data = pd.read_csv("grocery_sample.csv")
data
# Out:
#                    brand_name                                    item_name  \
# 0   Mrs. Barr's Natural Foods                                      Granola
# 1                       Giant                         French Artisan Rolls
# 2      Sprouts Farmers Market                               Kalamata Olive
# 3                 Yummy Earth                         Gummy Bears, Organic
# 4                      Nasoya                   Vegi-Dressing, Creamy Dill
# ..                        ...                                          ...
# 95               Lean Pockets  Sandwiches, Ham & Cheese, Whole Grain Crust
# 96                 Strathmore       Carbonated Natural Mineral Water, Lime
# 97                Davis Meats                               Smoked Sausage
# 98                   CapriSun            Flavored Juice Drink, Fruit Punch
# 99                 HMR Entree                     Bean and Beef Enchiladas
#
# ...
