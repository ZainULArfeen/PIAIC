# %%
with open("abc2.txt", mode="w") as f:
    f.write("Pakistan Zindabad!")

# %%
with open("abc2.txt", mode="w") as f:
    f.write("we are Pakistani") #truncates the values

# %% [markdown]
# # Append(A)

# %%
#it creates,writes,position at the end
with open("abc3.txt", "a") as f:
    f.write("hello world")

# %%
with open("abc3.txt", 'a') as f:
    f.write(" This is zain")

# %% [markdown]
# # A+

# %%
with open("abc4.txt", "a+") as f:
    f.seek(0)
    f.write("Hello World3!\n")
    c = f.readlines()
    print(c)
# Out:
# []

# %%
with open("abc5.txt", "r+") as f:
    a = list(reversed(f.readlines()))
    b = list(reversed(["A","B","C"])
# Out:
#   File "<ipython-input-22-3564a6ac0f21>", line 3
#     b = list(reversed(["A","B","C"])
#                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
open??

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread("./tom.jfif")
print(img.shape)
plt.imshow(img)
# Out:
# (179, 281, 3)
