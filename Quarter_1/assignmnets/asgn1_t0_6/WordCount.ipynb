# %% [markdown]
# # Word count exercise
# You are provided with a file named `alice.txt`. This file contains the famous story **Alice's Adventures in Wonderland**.
# your goal is to implement the following tasks using that file.

# %%
# Implement the function file_to_list that receives a filename 
# and returns a list of words in that file
# Use str.split() (no arguments) to split on all whitespace.
# for opening and reading a file, look for a functions open(...) and read lines(...)


def file_to_string():
    # your code here
    with open('alice.txt', 'r') as word_list:
        words = word_list.read().split()
    return words

file_to_string()
# Out:
# ["Alice's",
#  'Adventures',
#  'in',
#  'Wonderland',
#  "ALICE'S",
#  'ADVENTURES',
#  'IN',
#  'WONDERLAND',
#  'Lewis',
#  'Carroll',
#  'THE',
#  'MILLENNIUM',
#  'FULCRUM',
#  'EDITION',
#  '3.0',
#  'CHAPTER',
#  'I',
#  'Down',
#  'the',
#  'Rabbit-Hole',
#  'Alice',
#  'was',
#  'beginning',
#  'to',
#  'get',
#  'very',
#  'tired',
#  'of',
#  'sitting',
#  'by',
#  'her',
#  'sister',
#  'on',
#  'the',
#  'bank,',
#  'and',
#  'of',
#  'having',
#  'nothing',
#  'to',
#  'do:',
#  'once',
#  'or',
#  'twice',
#  'she',
#  'had',
#  'peeped',
#  'into',
#  'the',
#  'book',
#  'her',
#  'sister',
#  'was',
#  'reading,',
#  'but',
#  'it',
#  'had',
#  'no',
#  'pictures',
#  'or',
#  'conversations',
#  'in',
#  'it,',
#  '`and',
#  'what',
#  'is',
#  'the',
#  'use',
#  'of',
#  'a',
#  "book,'",
#  'thought',
#  'Alice',
#  '`without',
#  'pictures',
#  'or',
#  "conversation?'",
#  'So',
#  'she',
#  'was',
#  'considering',
#  'in',
#  'her',
#  'own',
#  'mind',
#  '(as',
#  'well',
#  'as',
#  'she',
#  'could,',
#  'for',
#  'the',
#  'hot',
#  'day',
#  'made',
#  'her',
#  'feel',
#  'very',
#  'sleepy',
#  'and',
#  'stupid),',
#  'whether',
#  'the',
#  'pleasure',
#  'of',
#  'making',
#  'a',
#  'daisy-chain',
#  'would',
#  'be',
#  'worth',
#  'the',
#  'trouble',
#  'of',
#  'getting',
#  'up',
#  'and',
#  'picking',
#  'the',
#  'daisies,',
#  'when',
#  'suddenly',
#  'a',
#  'White',
#  'Rabbit',
#  'with',
#  'pink',
#  'eyes',
#  'ran',
#  'close',
#  'by',
#  'her.',
#  'There',
#  'was',
#  'nothing',
#  'so',
#  'VERY',
#  'remarkable',
#  'in',
#  'that;',
#  'nor',
#  'did',
#  'Alice',
#  'think',
#  'it',
#  'so',
#  'VERY',
#  'much',
#  'out',
#  'of',
#  'the',
#  'way',
#  'to',
#  'hear',
#  'the',
#  'Rabbit',
#  'say',
#  'to',
#  'itself,',
#  '`Oh',
#  'dear!',
#  'Oh',
#  'dear!',
#  'I',
#  'shall',
#  'be',
#  "late!'",
#  '(when',
#  'she',
#  'thought',
#  'it',
#  'over',
#  'afterwards,',
#  'it',
#  'occurred',
#  'to',
#  'her',
#  'that',
#  'she',
#  'ought',
#  'to',
#  'have',
#  'wondered',
#  'at',
#  'this,',
#  'but',
#  'at',
#  'the',
#  'time',
#  'it',
#  'all',
#  'seemed',
#  'quite',
#  'natural);',
#  'but',
#  'when',
#  'the',
#  'Rabbit',
#  'actually',
#  'TOOK',
#  'A',
#  'WATCH',
#  'OUT',
#  'OF',
#  'ITS',
#  'WAISTCOAT-',
#  'POCKET,',
#  'and',
#  'looked',
#  'at',
#  'it,',
#  'and',
#  'then',
#  'hurried',
#  'on,',
#  'Alice',
#  'started',
#  'to',
#  'her',
#  'feet,',
#  'for',
#  'it',
#  'flashed',
#  'across',
#  'her',
#  'mind',
#  'that',
#  'she',
#  'had',
#  'never',
#  'before',
#  'seen',
#  'a',
#  'rabbit',
#  'with',
#  'either',
#  'a',
#  'waistcoat-pocket,',
#  'or',
#  'a',
#  'watch',
#  'to',
#  'take',
#  'out',
#  'of',
#  'it,',
#  'and',
#  'burning',
#  'with',
#  'curiosity,',
#  'she',
#  'ran',
#  'across',
#  'the',
#  'field',
#  'after',
#  'it,',
#  'and',
#  'fortunately',
#  'was',
#  'just',
#  'in',
#  'time',
#  'to',
#  'see',
#  'it',
#  'pop',
#  'down',
#  'a',
#  'large',
#  'rabbit-hole',
#  'under',
#  'the',
#  'hedge.',
#  'In',
#  'another',
#  'moment',
#  'down',
#  'went',
#  'Alice',
#  'after',
#  'it,',
#  'never',
#  'once',
#  'considering',
#  'how',
#  'in',
#  'the',
#  'world',
#  'she',
#  'was',
#  'to',
#  'get',
#  'out',
#  'again.',
#  'The',
#  'rabbit-hole',
#  'went',
#  'straight',
#  'on',
#  'like',
#  'a',
#  'tunnel',
#  'for',
#  'some',
#  'way,',
#  'and',
#  'then',
#  'dipped',
#  'suddenly',
#  'down,',
#  'so',
#  'suddenly',
#  'that',
#  'Alice',
#  'had',
#  'not',
#  'a',
#  'moment',
#  'to',
#  'think',
#  'about',
#  'stopping',
#  'herself',
#  'before',
#  'she',
#  'found',
#  'herself',
#  'falling',
#  'down',
#  'a',
#  'very',
#  'deep',
#  'well.',
#  'Either',
#  'the',
#  'well',
#  'was',
#  'very',
#  'deep,',
#  'or',
#  'she',
#  'fell',
#  'very',
#  'slowly,',
#  'for',
#  'she',
#  'had',
#  'plenty',
#  'of',
#  'time',
#  'as',
#  'she',
#  'went',
#  'down',
#  'to',
#  'look',
#  'about',
#  'her',
#  'and',
#  'to',
#  'wonder',
#  'what',
#  'was',
#  'going',
#  'to',
#  'happen',
#  'next.',
#  'First,',
#  'she',
#  'tried',
#  'to',
#  'look',
#  'down',
#  'and',
#  'make',
#  'out',
#  'what',
#  'she',
#  'was',
#  'coming',
#  'to,',
#  'but',
#  'it',
#  'was',
#  'too',
#  'dark',
#  'to',
#  'see',
#  'anything;',
#  'then',
#  'she',
#  'looked',
#  'at',
#  'the',
#  'sides',
#  'of',
#  'the',
#  'well,',
#  'and',
#  'noticed',
#  'that',
#  'they',
#  'were',
#  'filled',
#  'with',
#  'cupboards',
#  'and',
#  'book-shelves;',
#  'here',
#  'and',
#  'there',
#  'she',
#  'saw',
#  'maps',
#  'and',
#  'pictures',
#  'hung',
#  'upon',
#  'pegs.',
#  'She',
#  'took',
#  'down',
#  'a',
#  'jar',
#  'from',
#  'one',
#  'of',
#  'the',
#  'shelves',
#  'as',
#  'she',
#  'passed;',
#  'it',
#  'was',
#  'labelled',
#  '`ORANGE',
#  "MARMALADE',",
#  'but',
#  'to',
#  'her',
#  'great',
#  'disappointment',
#  'it',
#  'was',
#  'empty:',
#  'she',
#  'did',
#  'not',
#  'like',
#  'to',
#  'drop',
#  'the',
#  'jar',
#  'for',
#  'fear',
#  'of',
#  'killing',
#  'somebody,',
#  'so',
#  'managed',
#  'to',
#  'put',
#  'it',
#  'into',
#  'one',
#  'of',
#  'the',
#  'cupboards',
#  'as',
#  'she',
#  'fell',
#  'past',
#  'it.',
#  "`Well!'",
#  'thought',
#  'Alice',
#  'to',
#  'herself,',
#  '`after',
#  'such',
#  'a',
#  'fall',
#  'as',
#  'this,',
#  'I',
#  'shall',
#  'think',
#  'nothing',
#  'of',
#  'tumbling',
#  'down',
#  'stairs!',
#  'How',
#  'brave',
#  "they'll",
#  'all',
#  'think',
#  'me',
#  'at',
#  'home!',
#  'Why,',
#  'I',
#  "wouldn't",
#  'say',
#  'anything',
#  'about',
#  'it,',
#  'even',
#  'if',
#  'I',
#  'fell',
#  'off',
#  'the',
#  'top',
#  'of',
#  'the',
#  "house!'",
#  '(Which',
#  'was',
#  'very',
#  'likely',
#  'true.)',
#  'Down,',
#  'down,',
#  'down.',
#  'Would',
#  'the',
#  'fall',
#  'NEVER',
#  'come',
#  'to',
#  'an',
#  'end!',
#  '`I',
#  'wonder',
#  'how',
#  'many',
#  'miles',
#  "I've",
#  'fallen',
#  'by',
#  'this',
#  "time?'",
#  'she',
#  'said',
#  'aloud.',
#  '`I',
#  'must',
#  'be',
#  'getting',
#  'somewhere',
#  'near',
#  'the',
#  'centre',
#  'of',
#  'the',
#  'earth.',
#  'Let',
#  'me',
#  'see:',
#  'that',
#  'would',
#  'be',
#  'four',
#  'thousand',
#  'miles',
#  'down,',
#  'I',
#  "think--'",
#  '(for,',
#  'you',
#  'see,',
#  'Alice',
#  'had',
#  'learnt',
#  'several',
#  'things',
#  'of',
#  'this',
#  'sort',
#  'in',
#  'her',
#  'lessons',
#  'in',
#  'the',
#  'schoolroom,',
#  'and',
#  'though',
#  'this',
#  'was',
#  'not',
#  'a',
#  'VERY',
#  'good',
#  'opportunity',
#  'for',
#  'showing',
#  'off',
#  'her',
#  'knowledge,',
#  'as',
#  'there',
#  'was',
#  'no',
#  'one',
#  'to',
#  'listen',
#  'to',
#  'her,',
#  'still',
#  'it',
#  'was',
#  'good',
#  'practice',
#  'to',
#  'say',
#  'it',
#  'over)',
#  '`--yes,',
#  "that's",
#  'about',
#  'the',
#  'right',
#  'distance--but',
#  'then',
#  'I',
#  'wonder',
#  'what',
#  'Latitude',
#  'or',
#  'Longitude',
#  "I've",
#  'got',
#  "to?'",
#  '(Alice',
#  'had',
#  'no',
#  'idea',
#  'what',
#  'Latitude',
#  'was,',
#  'or',
#  'Longitude',
#  'either,',
#  'but',
#  'thought',
#  'they',
#  'were',
#  'nice',
#  'grand',
#  'words',
#  'to',
#  'say.)',
#  'Presently',
#  'she',
#  'began',
#  'again.',
#  '`I',
#  'wonder',
#  'if',
#  'I',
#  'shall',
#  'fall',
#  'right',
#  'THROUGH',
#  'the',
#  'earth!',
#  'How',
#  'funny',
#  "it'll",
#  'seem',
#  'to',
#  'come',
#  'out',
#  'among',
#  'the',
#  'people',
#  'that',
#  'walk',
#  'with',
#  'their',
#  'heads',
#  'downward!',
#  'The',
#  'Antipathies,',
#  'I',
#  "think--'",
#  '(she',
#  'was',
#  'rather',
#  'glad',
#  'there',
#  'WAS',
#  'no',
#  'one',
#  'listening,',
#  'this',
#  'time,',
#  'as',
#  'it',
#  "didn't",
#  'sound',
#  'at',
#  'all',
#  'the',
#  'right',
#  'word)',
#  '`--but',
#  'I',
#  'shall',
#  'have',
#  'to',
#  'ask',
#  'them',
#  'what',
#  'the',
#  'name',
#  'of',
#  'the',
#  'country',
#  'is,',
#  'you',
#  'know.',
#  'Please,',
#  "Ma'am,",
#  'is',
#  'this',
#  'New',
#  'Zealand',
#  'or',
#  "Australia?'",
#  '(and',
#  'she',
#  'tried',
#  'to',
#  'curtsey',
#  'as',
#  'she',
#  'spoke--fancy',
#  'CURTSEYING',
#  'as',
#  "you're",
#  'falling',
#  'through',
#  'the',
#  'air!',
#  'Do',
#  'you',
#  'think',
#  'you',
#  'could',
#  'manage',
#  'it?)',
#  '`And',
#  'what',
#  'an',
#  'ignorant',
#  'little',
#  'girl',
#  "she'll",
#  'think',
#  'me',
#  'for',
#  'asking!',
#  'No,',
#  "it'll",
#  'never',
#  'do',
#  'to',
#  'ask:',
#  'perhaps',
#  'I',
#  'shall',
#  'see',
#  'it',
#  'written',
#  'up',
#  "somewhere.'",
#  'Down,',
#  'down,',
#  'down.',
#  'There',
#  'was',
#  'nothing',
#  'else',
#  'to',
#  'do,',
#  'so',
#  'Alice',
#  'soon',
#  'began',
#  'talking',
#  'again.',
#  "`Dinah'll",
#  'miss',
#  'me',
#  'very',
#  'much',
#  'to-night,',
#  'I',
#  'should',
#  "think!'",
#  '(Dinah',
#  'was',
#  'the',
#  'cat.)',
#  '`I',
#  'hope',
#  "they'll",
#  'remember',
#  'her',
#  'saucer',
#  'of',
#  'milk',
#  'at',
#  'tea-time.',
#  'Dinah',
#  'my',
#  'dear!',
#  'I',
#  'wish',
#  'you',
#  'were',
#  'down',
#  'here',
#  'with',
#  'me!',
#  'There',
#  'are',
#  'no',
#  'mice',
#  'in',
#  'the',
#  'air,',
#  "I'm",
#  'afraid,',
#  'but',
#  'you',
#  'might',
#  'catch',
#  'a',
#  'bat,',
#  'and',
#  "that's",
#  'very',
#  'like',
#  'a',
#  'mouse,',
#  'you',
#  'know.',
#  'But',
#  'do',
#  'cats',
#  'eat',
#  'bats,',
#  'I',
#  "wonder?'",
#  'And',
#  'here',
#  'Alice',
#  'began',
#  'to',
#  'get',
#  'rather',
#  'sleepy,',
#  'and',
#  'went',
#  'on',
#  'saying',
#  'to',
#  'herself,',
#  'in',
#  'a',
#  'dreamy',
#  'sort',
#  'of',
#  'way,',
#  '`Do',
#  'cats',
#  'eat',
#  'bats?',
#  'Do',
#  'cats',
#  'eat',
#  "bats?'",
#  'and',
#  'sometimes,',
#  '`Do',
#  'bats',
#  'eat',
#  "cats?'",
#  'for,',
#  'you',
#  'see,',
#  'as',
#  'she',
#  "couldn't",
#  'answer',
#  'either',
#  'question,',
#  'it',
#  "didn't",
#  'much',
#  'matter',
#  'which',
#  'way',
#  'she',
#  'put',
#  'it.',
#  'She',
#  'felt',
#  'that',
#  'she',
#  'was',
#  'dozing',
#  'off,',
#  'and',
#  'had',
#  'just',
#  'begun',
#  'to',
#  'dream',
#  'that',
#  'she',
#  'was',
#  'walking',
#  'hand',
#  'in',
#  'hand',
#  'with',
#  'Dinah,',
#  'and',
#  'saying',
#  'to',
#  'her',
#  'very',
#  'earnestly,',
#  '`Now,',
#  'Dinah,',
#  'tell',
#  'me',
#  'the',
#  'truth:',
#  'did',
#  'you',
#  'ever',
#  'eat',
#  'a',
#  "bat?'",
#  'when',
#  'suddenly,',
#  'thump!',
#  'thump!',
#  'down',
#  'she',
#  'came',
#  'upon',
#  'a',
#  'heap',
#  'of',
#  'sticks',
#  'and',
#  'dry',
#  'leaves,',
#  'and',
#  'the',
#  'fall',
#  'was',
#  'over.',
#  'Alice',
#  'was',
#  'not',
#  'a',
#  'bit',
#  'hurt,',
#  'and',
#  'she',
#  'jumped',
#  'up',
#  'on',
#  'to',
#  'her',
#  'feet',
#  'in',
#  'a',
#  'moment:',
#  'she',
#  'looked',
#  'up,',
#  'but',
#  'it',
#  'was',
#  'all',
#  'dark',
#  'overhead;',
#  'before',
#  'her',
#  'was',
#  'another',
#  ...]

# %%
# implement a print_words(filename) function that counts
# how often each word appears in the text and prints:
# word1 count1
# word2 count2
# ...
# Print the above list in order sorted by word (python will sort punctuation to
# come before letters -- that's fine). Store all the words as lowercase,
# so 'The' and 'the' count as the same word.

def print_count(list_of_words):
    # you code here
    word_count = {}
    count_list = []
    with open(list_of_words, 'r') as wc:
        words = wc.read().lower().split()
        for word in words:
            if word not in word_count:
                word_count[word] = 0
            else:
                word_count[word] += 1
      
#     for key,value in word_count.items():
#         w_count = key , value
#         count_list.append(w_count)
    return sorted(word_count.items(), key=lambda x: x[0], reverse=False)
print_count('alice.txt')
# Out:
# [('"\'tis', 0),
#  ('"--said', 0),
#  ('"come', 1),
#  ('"coming', 0),
#  ('"edwin', 0),
#  ('"french,', 0),
#  ('"he\'s', 0),
#  ('"how', 1),
#  ('"i', 7),
#  ('"i\'ll', 1),
#  ('"it"', 1),
#  ('"keep', 0),
#  ('"let', 0),
#  ('"much', 0),
#  ('"poison"', 0),
#  ('"purpose"?\'', 0),
#  ('"such', 0),
#  ('"there', 1),
#  ('"there\'s', 0),
#  ('"they', 0),
#  ('"too', 0),
#  ('"turtle', 0),
#  ('"twinkle,', 0),
#  ('"uglification,"\'', 0),
#  ('"up', 0),
#  ('"what', 1),
#  ('"who', 0),
#  ('"william', 0),
#  ('"with', 0),
#  ('"you', 2),
#  ("'em", 2),
#  ("'tis", 1),
#  ('(`i', 1),
#  ("(`that's", 0),
#  ('(`the', 0),
#  ('(`which', 0),
#  ('(a', 0),
#  ('(alice', 3),
#  ('(and', 0),
#  ('(and,', 0),
#  ('(as', 2),
#  ('(before', 0),
#  ('(dinah', 0),
#  ('(for', 0),
#  ('(for,', 1),
#  ('(he', 0),
#  ('(if', 0),
#  ('(in', 0),
#  ('(it', 4),
#  ('(look', 0),
#  ('(luckily', 0),
#  ('(not', 0),
#  ('(or', 0),
#  ('(pointing', 0),
#  ('(she', 8),
#  ('(sounds', 0),
#  ('(the', 3),
#  ('(though', 0),
#  ('(we', 0),
#  ('(when', 0),
#  ('(which', 2),
#  ('(with', 1),
#  ('*', 59),
#  ('--but', 0),
#  ('--come,', 0),
#  ('--the', 0),
#  ('3.0', 0),
#  ('[later', 1),
#  ('_i_', 1),
#  ('`"--found', 0),
#  ('`"miss', 0),
#  ('`"we', 0),
#  ('`"what', 0),
#  ('`"will', 0),
#  ("`'tis", 1),
#  ('`--and', 1),
#  ('`--as', 0),
#  ('`--but', 0),
#  ('`--change', 0),
#  ('`--for', 0),
#  ('`--i', 0),
#  ('`--it', 0),
#  ('`--likely', 0),
#  ('`--mystery,', 0),
#  ('`--or', 0),
#  ('`--so', 1),
#  ('`--that', 0),
#  ('`--well', 0),
#  ("`--where's", 0),
#  ('`--yes,', 0),
#  ('`--you', 0),
#  ('`a', 10),
#  ('`advance', 0),
#  ('`after', 1),
#  ('`ah!', 1),
#  ('`ah,', 1),
#  ("`ahem!'", 0),
#  ("`alice!'", 0),
#  ('`all', 2),
#  ('`allow', 0),
#  ('`an', 0),
#  ('`and', 55),
#  ('`any', 0),
#  ('`anything', 0),
#  ('`are', 6),
#  ("`arrum.')", 0),
#  ('`as', 6),
#  ('`at', 2),
#  ('`back', 0),
#  ('`beautiful', 1),
#  ('`because', 2),
#  ('`begin', 0),
#  ('`behead', 0),
#  ('`besides,', 0),
#  ('`boots', 0),
#  ('`bring', 0),
#  ('`but', 37),
#  ('`but,', 0),
#  ('`by-the-bye,', 0),
#  ('`call', 3),
#  ('`can', 0),
#  ("`can't", 0),
#  ('`certainly', 0),
#  ('`change', 0),
#  ('`cheshire', 0),
#  ('`chop', 0),
#  ('`chorus', 0),
#  ('`collar', 0),
#  ('`come', 5),
#  ('`come,', 8),
#  ('`consider', 1),
#  ('`consider,', 0),
#  ("`creatures,'", 0),
#  ('`crumbs', 0),
#  ('`curiouser', 0),
#  ('`dear,', 0),
#  ('`did', 2),
#  ('`digging', 0),
#  ("`dinah'll", 0),
#  ("`dinah's", 0),
#  ('`do', 7),
#  ('`does', 1),
#  ("`don't", 5),
#  ('`drink', 2),
#  ('`drive', 0),
#  ('`each', 0),
#  ('`eat', 0),
#  ('`either', 0),
#  ('`everybody', 1),
#  ("`everything's", 0),
#  ('`exactly', 1),
#  ('`explain', 1),
#  ('`explanations', 0),
#  ('`fetch', 1),
#  ("`fifteenth,'", 0),
#  ('`first', 0),
#  ('`flamingoes', 0),
#  ('`for', 6),
#  ('`found', 1),
#  ('`fourteenth', 0),
#  ('`from', 0),
#  ('`fury', 0),
#  ('`get', 1),
#  ('`give', 2),
#  ('`go', 1),
#  ("`hadn't", 0),
#  ('`hand', 0),
#  ('`have', 2),
#  ('`he', 6),
#  ("`he's", 0),
#  ('`herald,', 0),
#  ('`here!', 1),
#  ("`here!'", 0),
#  ('`his', 0),
#  ("`hjckrrh!'", 0),
#  ('`hm!', 0),
#  ('`hold', 2),
#  ('`how', 15),
#  ('`however,', 0),
#  ('`hush!', 0),
#  ('`i', 120),
#  ("`i'd", 3),
#  ("`i'll", 4),
#  ("`i'm", 19),
#  ("`i've", 13),
#  ('`i--i', 0),
#  ("`i--i'm", 0),
#  ("`idiot!'", 0),
#  ('`if', 20),
#  ("`important,'", 0),
#  ('`important--unimportant--', 0),
#  ('`in', 7),
#  ('`is', 3),
#  ('`it', 29),
#  ("`it'll", 0),
#  ("`it's", 22),
#  ("`it's--it's", 0),
#  ("`jury-men'", 0),
#  ('`just', 2),
#  ('`keep', 0),
#  ('`leave', 1),
#  ('`let', 2),
#  ("`let's", 1),
#  ('`lives', 1),
#  ('`living', 0),
#  ('`look', 0),
#  ('`mary', 0),
#  ('`may', 0),
#  ('`mine', 0),
#  ("`moral,'", 0),
#  ('`mouse', 0),
#  ('`my', 1),
#  ('`nearly', 0),
#  ('`never', 0),
#  ("`never!'", 0),
#  ('`nine', 0),
#  ('`no', 1),
#  ('`no,', 8),
#  ("`no,'", 1),
#  ('`nobody', 1),
#  ("`nonsense!'", 0),
#  ('`nor', 0),
#  ('`not', 10),
#  ('`nothing', 2),
#  ("`nothing,'", 0),
#  ('`now', 4),
#  ('`now,', 3),
#  ('`o', 0),
#  ('`of', 11),
#  ('`off', 7),
#  ('`oh', 1),
#  ('`oh!', 1),
#  ('`oh,', 18),
#  ('`on', 0),
#  ('`once', 0),
#  ("`once,'", 0),
#  ('`one', 2),
#  ('`one,', 1),
#  ('`only', 2),
#  ('`only,', 0),
#  ('`or', 5),
#  ('`orange', 0),
#  ('`ou', 0),
#  ('`pepper,', 0),
#  ('`perhaps', 2),
#  ('`please', 2),
#  ('`please,', 0),
#  ("`poison,'", 1),
#  ('`poor', 0),
#  ('`pray', 0),
#  ('`prizes!', 0),
#  ('`read', 0),
#  ('`really', 0),
#  ('`really,', 1),
#  ('`reeling', 0),
#  ('`repeat,', 0),
#  ('`right,', 0),
#  ('`rule', 0),
#  ('`same', 0),
#  ('`seals,', 0),
#  ('`sentence', 0),
#  ("`serpent!'", 0),
#  ('`serpent,', 0),
#  ('`seven', 0),
#  ('`sh!', 0),
#  ('`shall', 1),
#  ("`shan't,'", 0),
#  ('`she', 3),
#  ("`she'd", 0),
#  ("`she's", 2),
#  ('`shy,', 0),
#  ('`silence', 0),
#  ("`silence!'", 0),
#  ('`sit', 1),
#  ("`sixteenth,'", 0),
#  ('`so', 6),
#  ('`soles', 0),
#  ('`some', 0),
#  ('`somebody', 0),
#  ('`soo--oop', 0),
#  ('`speak', 1),
#  ('`stand', 0),
#  ("`stolen!'", 0),
#  ('`stuff', 0),
#  ('`stupid', 1),
#  ("`stupid,'", 0),
#  ('`suppose', 1),
#  ('`sure', 0),
#  ('`sure,', 2),
#  ('`swim', 0),
#  ('`take', 1),
#  ('`talking', 0),
#  ('`tell', 1),
#  ('`ten', 0),
#  ('`than', 0),
#  ('`thank', 2),
#  ('`that', 14),
#  ("`that's", 14),
#  ('`the', 19),
#  ('`their', 0),
#  ('`then', 10),
#  ('`then,', 0),
#  ('`there', 3),
#  ("`there's", 6),
#  ('`they', 8),
#  ("`they'd", 0),
#  ("`they're", 2),
#  ("`they--you've", 0),
#  ('`thinking', 0),
#  ('`this', 2),
#  ('`three', 0),
#  ('`till', 1),
#  ('`to', 4),
#  ("`treacle,'", 1),
#  ('`turn', 1),
#  ('`tut,', 0),
#  ('`twenty-four', 0),
#  ('`twinkle,', 0),
#  ('`two', 1),
#  ("`ugh!'", 0),
#  ('`unimportant,', 1),
#  ("`unimportant.'", 0),
#  ('`unless', 0),
#  ('`until', 0),
#  ('`up,', 0),
#  ('`very', 3),
#  ("`very,'", 0),
#  ('`w.', 0),
#  ('`wake', 1),
#  ('`was,', 0),
#  ('`we', 10),
#  ("`we're", 0),
#  ('`well!', 1),
#  ("`well!'", 0),
#  ('`well,', 19),
#  ('`what', 33),
#  ('`what!', 0),
#  ("`what's", 2),
#  ('`when', 4),
#  ('`whenever', 0),
#  ('`where', 0),
#  ("`where's", 0),
#  ('`which', 2),
#  ('`who', 5),
#  ("`who's", 0),
#  ('`whoever', 0),
#  ('`why', 8),
#  ('`why,', 8),
#  ("`why,'", 1),
#  ("`why?'", 1),
#  ('`with', 0),
#  ('`without', 0),
#  ('`would', 4),
#  ("`wouldn't", 0),
#  ('`wow!', 1),
#  ('`write', 0),
#  ("`yes!'", 0),
#  ('`yes,', 7),
#  ("`yes,'", 2),
#  ('`you', 38),
#  ("`you!'", 0),
#  ("`you'd", 1),
#  ("`you'll", 1),
#  ("`you're", 5),
#  ("`you've", 0),
#  ('`your', 1),
#  ('a', 613),
#  ("a--'", 0),
#  ("a--i'm", 0),
#  ('a-piece', 0),
#  ('abide', 0),
#  ('able!', 0),
#  ('about', 83),
#  ("about!'", 0),
#  ('about,', 5),
#  ("about,'", 0),
#  ('about.', 0),
#  ('about;', 0),
#  ('above', 2),
#  ('absence,', 0),
#  ('absurd', 0),
#  ('absurd,', 0),
#  ('acceptance', 0),
#  ('accident', 0),
#  ('accident,', 0),
#  ('accidentally', 0),
#  ('account', 0),
#  ('accounting', 0),
#  ('accounts', 0),
#  ("accusation!'", 0),
#  ('accustomed', 0),
#  ("ache!'", 0),
#  ('across', 4),
#  ('act', 0),
#  ('actually', 0),
#  ("ada,'", 0),
#  ('added', 19),
#  ('added,', 2),
#  ('adding,', 0),
#  ('addressed', 1),
#  ('addressing', 0),
#  ('adjourn,', 0),
#  ('adoption', 0),
#  ('advance', 0),
#  ('advance!', 0),
#  ('advantage', 1),
#  ("advantage,'", 0),
#  ('adventures', 4),
#  ('adventures,', 0),
#  ('adventures--beginning', 0),
#  ("adventures.'", 0),
#  ('advice', 0),
#  ('advice,', 0),
#  ('advisable', 0),
#  ('advisable--"\'', 0),
#  ('advise', 0),
#  ('affair,', 0),
#  ('affectionately', 0),
#  ('afford', 0),
#  ('afore', 0),
#  ('afraid', 8),
#  ('afraid,', 1),
#  ("afraid,'", 0),
#  ('after', 39),
#  ('after-time,', 0),
#  ('afterwards,', 0),
#  ("afterwards.'", 0),
#  ('again', 12),
#  ('again!', 0),
#  ("again!'", 6),
#  ('again,', 30),
#  ("again,'", 0),
#  ('again--"before', 0),
#  ('again.', 15),
#  ("again.'", 1),
#  ('again.)', 0),
#  ('again:', 3),
#  ('again:--', 1),
#  ('again;', 1),
#  ("again?'", 1),
#  ('against', 8),
#  ('age', 1),
#  ('age,', 1),
#  ('ago', 0),
#  ('ago:', 0),
#  ('agony', 0),
#  ('agree', 1),
#  ('ah,', 0),
#  ('air', 1),
#  ('air!', 0),
#  ('air,', 4),
#  ('air.', 4),
#  ('air:', 0),
#  ('airs!', 0),
#  ('alarm', 0),
#  ('alarm.', 0),
#  ('alarmed', 0),
#  ('alas', 0),
#  ('alas!', 2),
#  ('alice', 220),
#  ('alice!', 2),
#  ("alice!'", 0),
#  ("alice's", 11),
#  ("alice's,", 0),
#  ('alice)--', 0),
#  ('alice,', 75),
#  ('alice,)', 1),
#  ('alice.', 53),
#  ('alice:', 6),
#  ('alice;', 15),
#  ('alive', 0),
#  ("alive!'", 0),
#  ('alive;', 0),
#  ('all', 154),
#  ('all!', 0),
#  ("all!'", 0),
#  ('all,', 2),
#  ("all,'", 3),
#  ('all.', 4),
#  ("all.'", 1),
#  ('all:', 1),
#  ('all;', 1),
#  ("all?'", 1),
#  ('allow', 1),
#  ('almost', 5),
#  ('alone', 1),
#  ("alone!'", 0),
#  ('alone.', 0),
#  ('along', 4),
#  ('along--`catch', 0),
#  ('aloud,', 0),
#  ('aloud.', 2),
#  ('aloud;', 0),
#  ('already', 0),
#  ('already,', 0),
#  ('also', 0),
#  ('also,', 0),
#  ("altered.'", 0),
#  ('alternately', 0),
#  ('altogether', 0),
#  ('altogether,', 1),
#  ('altogether.', 0),
#  ('altogether;', 0),
#  ('always', 11),
#  ('am', 12),
#  ('am!', 0),
#  ('am,', 0),
#  ('ambition,', 0),
#  ('among', 11),
#  ('an', 55),
#  ('ancient', 0),
#  ('and', 765),
#  ('and,', 18),
#  ('and--oh', 1),
#  ("and-butter--'", 0),
#  ('anger', 0),
#  ('anger,', 0),
#  ('angrily', 1),
#  ('angrily,', 2),
#  ('angrily.', 2),
#  ('angrily:', 0),
#  ('angry', 2),
#  ('angry,', 0),
#  ('angry.', 0),
#  ('animal', 0),
#  ("animal's", 0),
#  ('animals', 2),
#  ('animals,', 0),
#  ('ann!', 0),
#  ("ann!'", 0),
#  ('ann,', 1),
#  ('annoy,', 0),
#  ("annoyed,'", 0),
#  ('another', 20),
#  ('another!', 0),
#  ('answer', 5),
#  ('answer,', 0),
#  ('answer.', 0),
#  ("answer?'", 0),
#  ('answered', 2),
#  ('answered,', 0),
#  ("answers.'", 0),
#  ('antipathies,', 0),
#  ('anxious', 1),
#  ('anxious.)', 0),
#  ('anxiously', 12),
#  ('anxiously.', 0),
#  ('any', 35),
#  ("any,'", 0),
#  ('any.', 0),
#  ('anything', 13),
#  ('anything,', 0),
#  ('anything.', 0),
#  ('anything;', 1),
#  ('anywhere', 0),
#  ('appealed', 0),
#  ('appear', 0),
#  ('appear,', 0),
#  ('appearance', 0),
#  ('appeared', 2),
#  ('appeared,', 2),
#  ('appeared.', 0),
#  ('appeared;', 0),
#  ('appearing', 0),
#  ('applause,', 0),
#  ('apples,', 1),
#  ('arch', 0),
#  ('archbishop', 1),
#  ('arches', 2),
#  ('arches.', 0),
#  ('are', 39),
#  ('are!', 0),
#  ("are!'", 0),
#  ('are,', 1),
#  ("are,'", 0),
#  ('are;', 0),
#  ('argue.', 0),
#  ('argued', 0),
#  ('argument', 3),
#  ('arguments', 0),
#  ('arithmetic--', 0),
#  ('arm', 6),
#  ('arm,', 4),
#  ('arm-chair', 0),
#  ('arm-in-arm', 0),
#  ('arms', 4),
#  ('arms,', 0),
#  ('around', 1),
#  ('around,', 0),
#  ('arranged;', 0),
#  ('arrived,', 0),
#  ('arrow.', 0),
#  ('as', 248),
#  ('as,', 1),
#  ('ashamed', 1),
#  ('ask', 6),
#  ('ask!', 0),
#  ('ask.', 0),
#  ("ask.'", 0),
#  ('ask:', 0),
#  ('askance--', 0),
#  ('asked', 7),
#  ('asked,', 0),
#  ('asked.', 7),
#  ('asking', 2),
#  ('asking!', 0),
#  ('asking,', 0),
#  ('asleep', 3),
#  ('asleep,', 1),
#  ("asleep,'", 0),
#  ('asleep.', 0),
#  ('assembled', 1),
#  ('at', 205),
#  ('at!"', 0),
#  ('ate', 0),
#  ('atheling', 0),
#  ('atom', 1),
#  ('attempt', 0),
#  ('attempted', 0),
#  ('attempts', 0),
#  ('attended', 0),
#  ('attending', 1),
#  ("attending!'", 0),
#  ('attends', 0),
#  ('audibly.', 0),
#  ("australia?'", 0),
#  ('authority', 1),
#  ('avoid', 0),
#  ('away', 14),
#  ("away!'", 1),
#  ('away,', 2),
#  ("away,'", 0),
#  ('away.', 2),
#  ('away:', 0),
#  ('awfully', 0),
#  ("axes,'", 0),
#  ("axis--'", 0),
#  ('baby', 6),
#  ('baby,', 2),
#  ('baby:', 0),
#  ('baby;', 0),
#  ("baby?'", 0),
#  ('back', 28),
#  ("back!'", 1),
#  ('back,', 3),
#  ('back-somersault', 0),
#  ('back.', 1),
#  ('backs', 0),
#  ('bad', 0),
#  ('bad,', 0),
#  ('bag,', 0),
#  ('baked', 0),
#  ('balanced', 0),
#  ('balls', 0),
#  ('bank,', 1),
#  ('bank--the', 0),
#  ('banks,', 0),
#  ('banquet--]', 0),
#  ('bark', 1),
#  ('barking', 0),
#  ('barley-sugar', 0),
#  ('barrowful', 1),
#  ('bat!', 0),
#  ('bat,', 0),
#  ("bat?'", 0),
#  ('bathing', 0),
#  ('bats', 0),
#  ('bats,', 0),
#  ('bats?', 0),
#  ("bats?'", 0),
#  ('bawled', 0),
#  ('be', 137),
#  ("be!'", 0),
#  ('be"--or', 0),
#  ('be,', 0),
#  ("be,'", 2),
#  ("be.'", 0),
#  ("be?'", 1),
#  ('beak--', 0),
#  ('bear:', 0),
#  ('bear?--mind', 0),
#  ('beast,', 0),
#  ('beasts', 0),
#  ('beasts,', 0),
#  ('beat', 3),
#  ('beating', 0),
#  ('beating.', 0),
#  ('beau--ootiful', 3),
#  ('beauti--ful', 0),
#  ('beautiful', 7),
#  ('beautiful,', 2),
#  ('beautifully', 1),
#  ('beautify', 0),
#  ('became', 1),
#  ('because', 11),
#  ('become', 4),
#  ('becoming.', 0),
#  ("bed!'", 0),
#  ('beds', 0),
#  ('bee,"', 0),
#  ('been', 35),
#  ('been,', 0),
#  ('been.', 0),
#  ('before', 18),
#  ('before,', 10),
#  ("before,'", 2),
#  ('before.', 1),
#  ("before.'", 0),
#  ('beg', 7),
#  ('began', 46),
#  ('began,', 5),
#  ('began.', 2),
#  ('began:', 0),
#  ('began:--', 0),
#  ('begged', 0),
#  ('begin', 6),
#  ('begin,', 0),
#  ("begin.'", 2),
#  ("begin?'", 0),
#  ('beginning', 10),
#  ("beginning!'", 0),
#  ("beginning,'", 0),
#  ('begins', 3),
#  ('begun', 5),
#  ("begun.'", 0),
#  ("beheaded!'", 1),
#  ('beheaded,', 0),
#  ('beheading', 0),
#  ('behind', 11),
#  ("behind?'", 0),
#  ('being', 18),
#  ('believe', 7),
#  ("believe.'", 0),
#  ('believed', 0),
#  ('bells,', 0),
#  ('belong', 0),
#  ('belongs', 1),
#  ('beloved', 0),
#  ('below', 0),
#  ("below!'", 0),
#  ('below,', 0),
#  ('belt', 0),
#  ('bend', 0),
#  ('bend,', 0),
#  ('bent', 0),
#  ('besides', 0),
#  ('besides,', 1),
#  ('best', 8),
#  ('best,', 1),
#  ('best.', 0),
#  ('better', 10),
#  ("better';", 0),
#  ("better,'", 0),
#  ("better.'", 0),
#  ('between', 5),
#  ('bill', 1),
#  ('bill!', 2),
#  ("bill!'", 0),
#  ("bill's", 2),
#  ('bill,', 3),
#  ("bill,'", 1),
#  ('bird', 0),
#  ("bird,'", 0),
#  ('birds', 6),
#  ('birds!', 0),
#  ('birds,)', 0),
#  ('birthday', 0),
#  ('bit', 7),
#  ("bit!'", 0),
#  ('bit,', 1),
#  ("bit,'", 1),
#  ('bit.', 1),
#  ("bit.'", 0),
#  ("bite,'", 0),
#  ('bite.', 0),
#  ('bitter--and--and', 0),
#  ('blacking,', 0),
#  ('blades', 0),
#  ('blame', 0),
#  ('blasts', 1),
#  ('bleeds;', 0),
#  ('blew', 1),
#  ('blow', 1),
#  ('blown', 0),
#  ('blows', 0),
#  ('body', 1),
#  ('boldly:', 0),
#  ('bone', 0),
#  ('bones', 0),
#  ('book', 2),
#  ('book,', 1),
#  ("book,'", 1),
#  ('book-shelves;', 0),
#  ('books,', 0),
#  ('boon,', 0),
#  ('boots', 2),
#  ('bore', 0),
#  ('both', 13),
#  ('bother', 0),
#  ('bottle', 6),
#  ('bottle,', 1),
#  ('bottle.', 0),
#  ('bottom', 3),
#  ('bough', 0),
#  ('bound', 0),
#  ('bowed', 2),
#  ('bowed,', 0),
#  ('bowing', 0),
#  ('box', 2),
#  ('box--', 0),
#  ('boxed', 0),
#  ('boy,', 1),
#  ('boy--and', 0),
#  ('brain;', 0),
#  ('branch', 0),
#  ('branches', 0),
#  ('branches,', 0),
#  ('brass', 0),
#  ('brave', 0),
#  ('bread-', 0),
#  ('bread-and-butter', 1),
#  ('bread-and-butter,', 1),
#  ('bread-and-butter.', 0),
#  ("bread-knife.'", 0),
#  ('break', 0),
#  ('break.', 0),
#  ('breath,', 2),
#  ('breath."', 0),
#  ('breathe', 0),
#  ('breathe"!\'', 0),
#  ("breathe.'", 0),
#  ('breeze', 0),
#  ('bright', 6),
#  ('bright-eyed', 0),
#  ('brightened', 1),
#  ('bring', 1),
#  ('bringing', 2),
#  ('bristling', 0),
#  ('broke', 1),
#  ('broken', 4),
#  ('broken.', 0),
#  ("brother's", 0),
#  ('brought', 2),
#  ('brown', 0),
#  ('brown,', 0),
#  ('brush,', 0),
#  ('brushing', 0),
#  ('burn', 1),
#  ('burning', 0),
#  ('burnt,', 0),
#  ('burst', 0),
#  ('bursting', 0),
#  ('busily', 3),
#  ('business', 1),
#  ("business!'", 1),
#  ('business,', 0),
#  ("business,'", 0),
#  ("business?'", 0),
#  ('busy', 1),
#  ('but', 116),
#  ('but,', 7),
#  ('butter', 0),
#  ('butter,', 0),
#  ("butter,'", 0),
#  ('buttercup', 0),
#  ('buttered', 0),
#  ('butterfly,', 0),
#  ('buttons,', 0),
#  ('by', 55),
#  ('by--the', 0),
#  ('cackled', 0),
#  ('cake,', 1),
#  ('cake.', 0),
#  ('cakes', 0),
#  ('cakes,', 0),
#  ("cakes,'", 0),
#  ('call', 4),
#  ('called', 14),
#  ('calling', 0),
#  ('calmly,', 0),
#  ('came', 37),
#  ('came,', 1),
#  ('camomile', 0),
#  ('can', 30),
#  ("can't", 26),
#  ("can,'", 0),
#  ("can--'", 0),
#  ('can;', 0),
#  ('canary', 0),
#  ('candle', 1),
#  ('candle.', 0),
#  ('cannot', 0),
#  ('canterbury,', 0),
#  ('canvas', 0),
#  ('capering', 0),
#  ('capital', 3),
#  ('cardboard.)', 0),
#  ("cards!'", 0),
#  ('cards,', 0),
#  ('cards:', 0),
#  ('care', 3),
#  ('carefully,', 2),
#  ('cares', 1),
#  ('carried', 3),
#  ("carrier,'", 0),
#  ('carroll', 0),
#  ('carry', 0),
#  ('carrying', 1),
#  ('cart-horse,', 0),
#  ('cartwheels,', 0),
#  ('case', 3),
#  ("case,'", 0),
#  ('cat', 14),
#  ('cat!', 0),
#  ("cat's", 1),
#  ('cat,', 6),
#  ("cat,'", 1),
#  ('cat.', 5),
#  ('cat.)', 0),
#  ('cat:', 1),
#  ('cat;', 0),
#  ('catch', 2),
#  ('catching', 1),
#  ('caterpillar', 10),
#  ("caterpillar's", 0),
#  ('caterpillar,', 2),
#  ('caterpillar.', 11),
#  ('caterpillar;', 0),
#  ('cats', 8),
#  ("cats!'", 0),
#  ("cats.'", 0),
#  ('cats:', 0),
#  ("cats?'", 0),
#  ('cattle', 0),
#  ('caucus-race', 0),
#  ("caucus-race.'", 0),
#  ("caucus-race?'", 0),
#  ('caught', 2),
#  ('cauldron', 1),
#  ('cause', 1),
#  ('cause,', 0),
#  ('caused', 1),
#  ('cautiously', 1),
#  ('cautiously:', 0),
#  ('ceiling,', 0),
#  ('centre', 0),
#  ('certain', 1),
#  ('certain!', 0),
#  ('certainly', 7),
#  ("certainly,'", 2),
#  ('certainly:', 1),
#  ('chains,', 0),
#  ('chance', 3),
#  ('chanced', 0),
#  ('change', 8),
#  ('change,', 1),
#  ('change:', 0),
#  ('changed', 6),
#  ('changed,', 0),
#  ('changes', 1),
#  ('changing', 1),
#  ('chapter', 11),
#  ('character,', 0),
#  ('charges', 0),
#  ("chatte?'", 0),
#  ('cheap', 0),
#  ('cheated', 0),
#  ('checked', 2),
#  ('cheeks,', 0),
#  ('cheered,', 1),
#  ('cheered.', 0),
#  ('cheerfully', 0),
#  ('cherry-tart,', 0),
#  ('cheshire', 5),
#  ('chief', 0),
#  ('child', 2),
#  ("child!'", 1),
#  ('child,', 0),
#  ("child,'", 0),
#  ('child-life,', 0),
#  ('child:', 0),
#  ('child;', 0),
#  ("child?'", 0),
#  ('childhood:', 0),
#  ('children', 4),
#  ('children,', 2),
#  ('children.', 0),
#  ('children;', 0),
#  ('chimney', 1),
#  ("chimney!'", 0),
#  ('chimney,', 1),
#  ('chimney?--nay,', 0),
#  ('chimneys', 0),
#  ('chin', 3),
#  ('chin.', 1),
#  ('chin:', 0),
#  ("choice!'", 0),
#  ('choice,', 0),
#  ('choke', 0),
#  ('choked', 2),
#  ...]

# %%
# implement a print_top(filename) which is similar
# to print_words() but which prints just the top 20 most common words sorted
# so the most common word is first, then the next most common, and so on.


def print_top(list_of_words):
    #your code here
    word_count = {}
    top_20 = []
    with open(list_of_words, 'r') as wc:
        words = wc.read().lower().split()
        for word in words:
            if word not in word_count:
                word_count[word] = 0
            else:
                word_count[word] += 1
    
    items = sorted(word_count.items(), key=lambda x: x[1], reverse=True)
    
    
    return items[0:20]

print_top('alice.txt')
# Out:
# [('the', 1604),
#  ('and', 765),
#  ('to', 705),
#  ('a', 613),
#  ('she', 517),
#  ('of', 492),
#  ('said', 420),
#  ('it', 361),
#  ('in', 351),
#  ('was', 332),
#  ('you', 264),
#  ('i', 260),
#  ('as', 248),
#  ('that', 221),
#  ('alice', 220),
#  ('her', 207),
#  ('at', 205),
#  ('had', 175),
#  ('with', 168),
#  ('all', 154)]
